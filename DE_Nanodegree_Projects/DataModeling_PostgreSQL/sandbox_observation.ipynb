# %%
import pandas as pd

# %%
# Looking at an exemple of data log
df = pd.read_json('data/log_data/2018/11/2018-11-18-events.json', lines=True)
df
# Out:
#               artist       auth   firstName gender  itemInSession  lastName  \
# 0    Rokia TraorÃÂ©  Logged In     Stefany      F              0     White
# 1               None  Logged In      Tucker      M              0  Garrison
# 2             Camila  Logged In      Tucker      M              1  Garrison
# 3               None  Logged In         Ann      F              0     Banks
# 4        Carl Thomas  Logged In      Tucker      M              0  Garrison
# ..               ...        ...         ...    ...            ...       ...
# 152           Weezer  Logged In  Jacqueline      F            126     Lynch
# 153     Gary Stewart  Logged In       Chloe      F              8    Cuevas
# 154             None  Logged In  Jacqueline      F            127     Lynch
# 155             None  Logged In       Aiden      M              0      Hess
# 156     Travie McCoy  Logged In       Aiden      M              1      Hess
#
# ...

# %%
df = pd.read_json('data/song_data/A/A/A/TRAAABD128F429CF47.json', lines=True)
df
# Out:
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARMJAGH1187FB546F3         35.14968         -90.04892
#
#   artist_location   artist_name             song_id      title   duration  \
# 0     Memphis, TN  The Box Tops  SOCIWDW12A8C13D406  Soul Deep  148.03546
#
#    year
# 0  1969
